# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import dask.dataframe as dd
from pathlib import Path

import os

DATA_DIR = Path('../backend/api/data')
RAW_DATA = DATA_DIR / 'raw'
PROCESSED_DATA = DATA_DIR / 'processed'
INFOBUSES = RAW_DATA / 'buses'
# print(os.listdir(RAW_DATA))
df = dd.read_csv(RAW_DATA / '2018-04-29.profile', sep='|', encoding='latin1')
df
# Out:
# ['buses_sample', 'buses', '2018-05-01.viajes.csv', 'sample.gps.csv', 'paraderos_2018-1.xlsx', 'profile.sample.csv', 'Zonas777', '2018-04-29.profile']
# Dask DataFrame Structure:
#               Operador ServicioSentido ServicioUsuario Patente Paradero NombreParada    Hini    Hfin Cumplimiento Correlativo idExpedicion DistEnRuta #Subidas #SubidasLejanas Subidastotal SubidasExpandidas #Bajadas #BajadasLejanas Bajadastotal BajadasExpandidas    Carga Capacidad TiempoGPSInterpolado TiempoPrimeraTrx TiempoGPSMasCercano  Tiempo nSubidasTmp ParaderoUsuario PeriodoTSExpedicion PeriodoTSParada TipoDia     ZP DeltaTrxs MHSalida MHPasada ExpedicionConProblema ServicioUsuarioTS
# npartitions=9
#                  int64          string           int64  string   string       string  string  string       string       int64        int64      int64    int64           int64        int64           float64    int64           int64        int64             int64  float64     int64               string           string              string  string       int64          string               int64           int64   int64  int64     int64    int64    int64                 int64             string
#                    ...             ...             ...     ...      ...          ...     ...     ...          ...         ...          ...        ...      ...             ...          ...               ...      ...             ...          ...               ...      ...       ...                  ...              ...                 ...     ...         ...             ...                 ...             ...     ...    ...       ...      ...      ...                   ...                ...
# ...                ...             ...             ...     ...      ...          ...     ...     ...          ...         ...          ...        ...      ...             ...          ...               ...      ...             ...          ...               ...      ...       ...                  ...              ...                 ...     ...         ...             ...                 ...             ...     ...    ...       ...      ...      ...                   ...                ...
#                    ...             ...             ...     ...      ...          ...     ...     ...          ...         ...          ...        ...      ...             ...          ...               ...      ...             ...          ...               ...      ...       ...                  ...              ...                 ...     ...         ...             ...                 ...             ...     ...    ...       ...      ...      ...                   ...                ...
#                    ...             ...             ...     ...      ...          ...     ...     ...          ...         ...          ...        ...      ...             ...          ...               ...      ...             ...          ...               ...      ...       ...                  ...              ...                 ...     ...         ...             ...                 ...             ...     ...    ...       ...      ...      ...                   ...                ...
# Dask Name: to_pyarrow_string, 2 graph layers

# %% [markdown]
# # Análisis de los datos
